# %%
print("OPPOSITE GAME\n")
color= input("which color is grass?")
team= input("What is the worst football team?")
food= input("Which is your worst food?")
answer=input("Do you want to see your answers? Enter yes or no")
if answer.upper() =="YES":
    print("Roses are" +" "+ color)
    print("I love "+" "+ team)
    print("My best food is"+" "+ food)
else:
    print("GOODBYE👋👋👋👋👋")

# %%
print("CONVERTING KGS TO LBS")
print("Enter kgs you want to convert to lbs")
kg= float(input("Enter kgs you want to convert\n"))
print(f"{kg} kgs")
print("After conversion...")
lbs= float(kg*2.2046)
print(f"The answer is {lbs} lbs")

# %%
print("CALCULATING CIRCUMFRENCE and AREA OF A CIRCLE")
p= 3.14
print("Radius of the circle is...")
r= float(input("Enter the radius of your circle in centimetres" ))
print(f"{r} cm")
print("After calculation...")
d= float(r*2)
circumfrence=  p*d 
area= p*pow(r,2)
print(f"The circumfrence of your circle is {circumfrence} cm")
print(f"The area of your circle is {area} cm")

# %%
print("TIP CALCULATOR\n")
print("The price you were charged is...")
price= int(input("Enter the price you were charged:"))
print(f"${price}")
print("Percentage you want to tip is...")
percent= int(input("Enter the percentage you want to tip: "))
print(f"{percent} %")
tip= int((percent/100)*price)
print("Amount you want to tip is....")
print(f"${tip}")

# %%
import random
print("WORD GUESSING GAME\n")
words = ["KETTLE","MANTLE","ABYSS","GOLDEN","EXPERIENCED","BRANDING","RECKON","CRIMSON","PROTECT","IMPALA","HELSINKI","CASTLE"]
random= random.choice(words)
hint= ""
length= len(random)


if random== "KETTLE":
    hint= "utensil"
    print(f"THE HINT IS-----> {hint}")
elif random== "MANTLE":
    hint= "geography "
    print(f"THE HINT IS-----> {hint}")
elif random== "ABYSS":
    hint= "landform "
    print(f"THE HINT IS-----> {hint}")
elif random== "GOLDEN":
    hint= "adjective "
    print(f"THE HINT IS-----> {hint}")
elif random== "EXPERIENCED":
    hint= "quality "
    print(f"THE HINT IS-----> {hint}")
elif random== "BRANDING":
    hint= "business"
    print(f"THE HINT IS-----> {hint}")
elif random== "RECKON":
    hint= "verb"
    print(f"THE HINT IS-----> {hint}")
elif random== "CRIMSON":
    hint= "color"
    print(f"THE HINT IS-----> {hint}")
elif random== "PROTECT":
    hint= "verb"
    print(f"THE HINT IS-----> {hint}")
elif random== "IMPALA":
    hint= "animal"
    print(f"THE HINT IS-----> {hint}")
elif random== "HELSINKI":
    hint= "city"
    print(f"THE HINT IS-----> {hint}")
else:
    hint= "building"
    print(f"THE HINT IS-----> {hint}")

print(f"THE WORD HAS-----> {length} <------ LETTERS\n")

wrong=[]
guesss=""

guesscount= 10
maxguess= 10
while guesss!=random:
        guesss= input("GUESS THE WORD")
        guess= guesss.upper()
        print(" ")
        if guess==random:
            print("YOU WIN🎉🎉🎉🎉🎊🎊🥳🥳")
            print(f"THE WORD IS {random}")
            break
        else:
            wrong.append(guess)
            print(f"WORDS YOU HAVE ALREADY GUESSED----- {wrong}")
            print(f"YOU HAVE {guesscount} GUESSES REMAINING!!!!")
            guesscount-=1
            maxguess-=1
        if maxguess==0:
            print("YOU LOSE😭😭😭😞😞")
            print(f"THE WORD IS {random}")

# %%
def hello():
   # name= input("What is your name?")
    #return "Hello" + name
    print ("Hello")

hello()
